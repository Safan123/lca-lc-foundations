# %%
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver
from pprint import pprint
from typing import Dict, Any
from tavily import TavilyClient

# %%
load_dotenv()
# Out:
# True

# %%
system_prompt = """
Be brief. You are cullinar Chef, with access to web. Based on ingredients i will tell you, find me receipe in internet based on given ingredients. Than ask me if it's ok to buy 
some more needed ingredients, and than propose meal with ingredients i have and the ones i decided to buy, and than present it to me with given formula. 
Ingredients: listed ingredients with volumes
Preparation phase: listed preparation phase
Cooking phase: listed cooking steps.
"""

# %%
tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for receipes"""
    return tavily_client.search(query)

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    checkpointer=InMemorySaver()
)

# %%
config = {"configurable": {"thread_id": "1"}}
prompt = HumanMessage(content="Hey, make me a meal with paprica, chicken breasts and chow main.")

# %%
response = agent.invoke(
    {"messages": [prompt]},
    config
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hey, make me a meal with paprica, chicken breasts and chow main.', additional_kwargs={}, response_metadata={}, id='5b07e0a8-356f-4757-8d9b-ad9459af6245'),
#               AIMessage(content='Nice choice. Here’s a simple, tasty Paprika Chicken with Chow Mein Noodles you can make in about 30–40 minutes.\n\nServings: 4\nTotal time: ~35 minutes\n\nIngredients\n- 2 boneless, skinless chicken breasts (about 1 lb), cut into thin strips\n- 2 tablespoons paprika (smoked or sweet, depending on your taste)\n- 1 teaspoon garlic powder\n- 1/2 teaspoon salt\n- 1/4 teaspoon black pepper\n- 2 tablespoons olive oil (or any neutral oil)\n- 1 small onion, sliced\n- 1 red bell pepper, sliced\n- 1 cup mushrooms, sliced (optional)\n- 2 cloves garlic, minced\n- 8 oz chow mein noodles (dry) or chow mein noodles (fresh), cooked according to package\n- 1/4 cup low-sodium soy sauce\n- 1/4 cup chicken broth (or water)\n- 1 tablespoon honey or brown sugar\n- 1 teaspoon rice vinegar or mirin (optional)\n- 1 tablespoon sesame oil (for finish)\n- Green onions, sliced (for garnish)\n- Sesame seeds (for garnish)\n\nInstructions\n1) Cook the chow mein noodles according to package instructions. If using dry noodles, cook until al dente, drain, and toss with a tiny bit of oil to prevent sticking. Set aside.\n2) In a bowl, toss the chicken strips with paprika, garlic powder, salt, and pepper.\n3) Heat the olive oil in a large skillet over medium-high heat. Add the chicken and sear until browned and cooked through, about 5–7 minutes. Transfer to a plate.\n4) In the same skillet, add the onion, bell pepper, and mushrooms. Sauté 3–4 minutes until just tender. Add the minced garlic and cook 30 seconds more.\n5) Return the chicken to the pan. Stir in soy sauce, chicken broth, honey, and vinegar. Bring to a gentle simmer and cook 2–3 minutes to meld the flavors.\n6) Add the cooked chow mein noodles to the skillet. Toss to coat and heat through, about 1–2 minutes.\n7) Drizzle with sesame oil, taste, and adjust salt if needed.\n8) Garnish with sliced green onions and a sprinkle of sesame seeds. Serve warm.\n9) Optional: Serve with a simple side like a cucumber-dill salad or steamed broccoli for balance.\n\nTips and variations\n- If you like it smoky, use smoked paprika.\n- For extra heat, add a pinch of red pepper flakes or a splash of chili paste.\n- Gluten-free option: use tamari instead of soy sauce.\n- If you don’t have chow mein noodles, you can use any thin pasta or even rice noodles.\n\nWould you like me to tailor this to your pantry (for example, swap noodles for rice, or adjust spice level)? Also tell me how many servings you want and any dietary restrictions.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1835, 'prompt_tokens': 141, 'total_tokens': 1976, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DVOvgzA1sTtWYxvgnNhMgGEY08QBF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9848-48ce-7c90-b7c1-ae71c24fd9d8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 141, 'output_tokens': 1835, 'total_tokens': 1976, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}})]}

# %%
pprint(response['messages'][1].content)
# Out:
# ('Nice choice. Here’s a simple, tasty Paprika Chicken with Chow Mein Noodles '
#  'you can make in about 30–40 minutes.\n'
#  '\n'
#  'Servings: 4\n'
#  'Total time: ~35 minutes\n'
#  '\n'
#  'Ingredients\n'
#  '- 2 boneless, skinless chicken breasts (about 1 lb), cut into thin strips\n'
#  '- 2 tablespoons paprika (smoked or sweet, depending on your taste)\n'
#  '- 1 teaspoon garlic powder\n'
#  '- 1/2 teaspoon salt\n'
#  '- 1/4 teaspoon black pepper\n'
#  '- 2 tablespoons olive oil (or any neutral oil)\n'
#  '- 1 small onion, sliced\n'
#  '- 1 red bell pepper, sliced\n'
#  '- 1 cup mushrooms, sliced (optional)\n'
#  '- 2 cloves garlic, minced\n'
#  '- 8 oz chow mein noodles (dry) or chow mein noodles (fresh), cooked '
#  'according to package\n'
#  '- 1/4 cup low-sodium soy sauce\n'
#  '- 1/4 cup chicken broth (or water)\n'
#  '- 1 tablespoon honey or brown sugar\n'
#  '- 1 teaspoon rice vinegar or mirin (optional)\n'
#  '- 1 tablespoon sesame oil (for finish)\n'
#  '- Green onions, sliced (for garnish)\n'
#  '- Sesame seeds (for garnish)\n'
#  '\n'
#  'Instructions\n'
#  '1) Cook the chow mein noodles according to package instructions. If using '
#  'dry noodles, cook until al dente, drain, and toss with a tiny bit of oil to '
#  'prevent sticking. Set aside.\n'
#  '2) In a bowl, toss the chicken strips with paprika, garlic powder, salt, and '
#  'pepper.\n'
#  '3) Heat the olive oil in a large skillet over medium-high heat. Add the '
#  'chicken and sear until browned and cooked through, about 5–7 minutes. '
#  'Transfer to a plate.\n'
#  '4) In the same skillet, add the onion, bell pepper, and mushrooms. Sauté 3–4 '
#  'minutes until just tender. Add the minced garlic and cook 30 seconds more.\n'
#  '5) Return the chicken to the pan. Stir in soy sauce, chicken broth, honey, '
#  'and vinegar. Bring to a gentle simmer and cook 2–3 minutes to meld the '
#  'flavors.\n'
#  '6) Add the cooked chow mein noodles to the skillet. Toss to coat and heat '
#  'through, about 1–2 minutes.\n'
#  '7) Drizzle with sesame oil, taste, and adjust salt if needed.\n'
#  '8) Garnish with sliced green onions and a sprinkle of sesame seeds. Serve '
#  'warm.\n'
#  '9) Optional: Serve with a simple side like a cucumber-dill salad or steamed '
#  'broccoli for balance.\n'
#  '\n'
#  'Tips and variations\n'
#  '- If you like it smoky, use smoked paprika.\n'
#  '- For extra heat, add a pinch of red pepper flakes or a splash of chili '
#  'paste.\n'
#  '- Gluten-free option: use tamari instead of soy sauce.\n'
#  '- If you don’t have chow mein noodles, you can use any thin pasta or even '
#  'rice noodles.\n'
#  '\n'
#  'Would you like me to tailor this to your pantry (for example, swap noodles '
#  'for rice, or adjust spice level)? Also tell me how many servings you want '
#  'and any dietary restrictions.')
