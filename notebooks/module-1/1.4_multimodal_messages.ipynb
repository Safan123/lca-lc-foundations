# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime. It sits on the rim of Shackleton Crater near the lunar south pole, wrapped in near-constant daylight from expansive solar shades.
#
# - Governance: The executive seat of the Lunar Confederation, with Parliament housed inside the central Sol Dome.
# - Architecture: Terraced districts hewn from basalt and reinforced with translucent polyglass, connected by lift rails and a glass-floored promenade that circles the crater.
# - Life: Engineers, miners, scientists, and diplomats share the city’s glow, living by a motto carved into the civic walls: “Light from shadow.”
#
# If you’d like a different vibe (gritty, utopian, corporate, etc.), I can tailor Lunaris Prime accordingly or propose another name and location.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'DII_Arrakis.png', 'type': 'image/png', 'size': 38702, 'content': <memory at 0x00000297FBDE2500>, 'last_modified': datetime.datetime(2026, 4, 16, 20, 2, 32, 17000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this planet"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Nice image. Here’s a vivid portrait of the desert world it suggests.
#
# Planet: Xyra
# - Location in system: A dry world orbiting a pale orange dwarf. A thin blue haze marks its atmosphere at the limb, and two small moons drift in the background.
# - Size and gravity: About the size of Earth (roughly 0.95–1.0 R⊕); gravity near 0.9–1.0 g, so things feel sturdy but not heavy.
# - Day and tilt: A sidereal day around 26–28 hours. Axial tilt modest, so seasons are noticeable but not extreme.
#
# Surface and climate
# - Geography: Over half the surface is a vast, sun-baked desert of coppery dunes and glassy salt flats. Rugged basalt mesas and canyon networks rise in the midlatitude belts, where water carves slow, deep channels that vanish into underground reservoirs.
# - Climate: Extreme diurnal swings—blistering days that rival hot springs of 50–55 C near the equator, and surprisingly chilly nights as the heat drains away. Dust storms can blanket regions for days, whipping up iron-rich particulates that glitter in the sun.
# - Hydrology: Water is mostly locked in subterranean aquifers and seasonal oases fed by rare rain events. Surface water bodies are few and highly saline, often ringed by mineral terraces.
#
# Life and ecology
# - Surface life: Sparse, tough, and colorful in the right light. Iron-oxide–streaked lichens cling to rock faces; hardy mosses inhabit salty depressions after rare rains. On dunes, wind-dispersed seeds germinate only after a perfect moisture pulse.
# - Subsurface life: A web of troglobiont animals and microbes thrives in aquifers and cave networks, some with bioluminescent pockets that glow in the long underground tunnels.
# - Possible inhabitants: If sentient species exist, they are likely to be highly water-efficient and science-driven, with cultures built around managing scarce resources and tracing the hidden water networks.
#
# Technology and society (high level)
# - Inhabitants and culture: Two broad currents tend to define Xyra’s societies—water-systems engineers who map aquifers and run desalination/atmosphere machines, and dune-borne nomads who traverse the desert with wind-sail caravans. A third, more secretive faction, guards access to ancient cave-complexes containing preserved knowledge.
# - Economy: Water rights and minerals from the glassy flats are primary. Solar and wind power dominate energy grids; heat is harvested from geothermal vents in the mesas for industry and living spaces.
# - Architecture: Many settlements cluster around geothermal plateaus or water-bearing ridges. Buildings favor heat-resistant glass and stone, with shaded courtyards, wind towers, and reflective surfaces that manage heat and light.
#
# A few story seeds (optional)
# - Monsoon season reveals a buried ruin beneath a salt flat, changing maps and power balances as new corridors fill with water.
# - A dust storm uncovers a mining accident’s long-lost tunnel, releasing ancient machinery and a legacy that could upend current politics.
# - A wave of bioluminescent cave organisms spills into an underground aquifer, drawing explorers and ecologists—and a competitor who wants ownership of the bioluminescent species.
#
# Would you like me to sketch a capital city for Xyra? If yes, tell me the vibe you want (futuristic glass-and-steel, ancient-rock-and-crystal, subterranean metropolis, etc.), and I’ll design a detailed city with districts, notable landmarks, and daily life.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[8], line 13
#      10 sample_rate = 44100
#      12 print("Recording...")
# ---> 13 audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
#      14 # Progress bar for the duration
#      15 for _ in tqdm(range(duration * 10)):   # update 10× per second
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:284, in rec(frames, samplerate, channels, dtype, out, mapping, blocking, **kwargs)
#     281     ctx.read_indata(indata)
#     282     ctx.callback_exit()
# --> 284 ctx.start_stream(InputStream, samplerate, ctx.input_channels,
#     285                  ctx.input_dtype, callback, blocking, **kwargs)
#     286 return out
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:2664, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2661 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2662                  blocking, **kwargs):
#    2663     stop()  # Stop previous playback/recording
# -> 2664     self.stream = StreamClass(samplerate=samplerate,
#    2665                               channels=channels,
#    2666                               dtype=dtype,
#    2667                               callback=callback,
#    2668                               finished_callback=self.finished_callback,
#    2669                               **kwargs)
#    2670     self.stream.start()
#    2671     global _last_callback
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:1457, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1425 def __init__(self, samplerate=None, blocksize=None,
#    1426              device=None, channels=None, dtype=None, latency=None,
#    1427              extra_settings=None, callback=None, finished_callback=None,
#    1428              clip_off=None, dither_off=None, never_drop_input=None,
#    1429              prime_output_buffers_using_stream_callback=None):
#    1430     """PortAudio input stream (using NumPy).
#    1431
#    1432     This has the same methods and attributes as `Stream`, except
#    (...)   1455
#    1456     """
# -> 1457     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1458                          **_remove_self(locals()))
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:833, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     830         samplerate = isamplerate
#     831 else:
#     832     parameters, self._dtype, self._samplesize, samplerate = \
# --> 833         _get_stream_parameters(kind, device, channels, dtype, latency,
#     834                                extra_settings, samplerate)
#     835     self._device = parameters.device
#     836     self._channels = parameters.channelCount
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:2750, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2747 if samplerate is None:
#    2748     samplerate = default.samplerate
# -> 2750 info = query_devices(device)
#    2751 if channels is None:
#    2752     channels = info['max_' + kind + '_channels']
#
# File ~\Documents\GitHub\lca-lc-foundations\.venv\Lib\site-packages\sounddevice.py:577, in query_devices(device, kind)
#     575 info = _lib.Pa_GetDeviceInfo(device)
#     576 if not info:
# --> 577     raise PortAudioError(f'Error querying device {device}')
#     578 assert info.structVersion == 2
#     579 name_bytes = _ffi_string(info.name)
#
# PortAudioError: Error querying device -1

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
