# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. It’s a natural satellite with no permanent population, so no political entities or capitals exist there. (In fiction people sometimes invent capitals like “Lunapolis,” but that’s not real.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 577, 'prompt_tokens': 13, 'total_tokens': 590, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DV2kJNd5xBrNwLgQ4Tg1h2ssV4P1t', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9333-1ef1-79d0-acf7-0dc7de13a1ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 577, 'total_tokens': 590, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. It’s a natural satellite with no permanent population, so no political entities or capitals exist there. (In fiction people sometimes invent capitals like “Lunapolis,” but that’s not real.)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DV2kJNd5xBrNwLgQ4Tg1h2ssV4P1t',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 577,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 590}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no capital or government. It’s a natural satellite of Earth; humans have visited and built temporary bases, but there’s no sovereign administration there. If you want, I can share more about lunar missions or bases.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6c9339d8-1e76-462c-b6c6-ee3779e672b3'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re asking in a fictional or joke context, tell me the universe and I can suggest a name.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1078, 'prompt_tokens': 13, 'total_tokens': 1091, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DVIrkRUB1YIr4AOspLLmRZsEAnkzK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d96e4-a317-7770-a9d3-7ac0beed2fc6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1078, 'total_tokens': 1091, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or sovereign entity, so it has no capital.
#
# If you’re thinking in fiction, people sometimes invent lunar capitals with names like Lunapolis, Selene, or Moon City. Want me to suggest some world-building ideas or names for a story?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='36ce324d-88d9-42b3-be02-82b9cdb3c56e'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='5c6418dc-7230-44e1-a319-39f5a4c4b244', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='08acb1a2-0a2d-4159-8cdc-d215c93e0eb1'),
#               AIMessage(content='Great—since Luna City isn’t a real place, I’ll treat it as a fictional setting. Here’s a flavor of what Luna City could be like as the capital of a Moon-based polity.\n\n- Concept and location\n  - Luna City sits in the lunar south polar region, on a sunlit rim of a crater that’s mined for water ice and sheltered by ice regolith shielding. The near-continuous sunlight on that rim feeds large solar farms, while subsurface ice provides life support and fuel for future industry.\n  - It’s the political and cultural capital of the Lunar Confederation (or Lunar Republic), where representatives from lunar settlements, Earth-oceanic exchanges, and orbital organizations gather.\n\n- Government and society\n  - The Luna City Council governs with a hybrid system: elected representatives from districts, expert advisory boards (science, engineering, and ethics), and a rotating Earth-Ops liaison for interplanetary coordination.\n  - Society is multilingual and multinational: engineers from Earth, researchers from Mars outposts, and settlers from new moon habitats. Robots and AI assist everyday life and keep essential systems running.\n  - The calendar runs on a lunar cycle (roughly 28–29 days), with a clear rhythm of two “sunrise seasons” and a long “night season” that drives culture, science schedules, and festivals.\n\n- City design and districts\n  - The core is an arcology complex called the Council Dome, a reinforced habitat cluster with crystalline solar canopies and ice-shielded interiors.\n  - Districts include:\n    - The Icewell Market: a floating market built around cryo-storage and resource exchanges.\n    - The Lumen District: homes and labs wrapped in basalt-printed shells with warm interiors and transparent geodesic atria.\n    - The Observatory Quarter: research facilities, telescopes, and public viewing decks for Earthrise and distant targets.\n    - The Transit Spine: a network of pressurized tunnels and maglev lines connecting surface habitats to orbital relays.\n  - Architecture blends rugged, utilitarian modules with aesthetic glassy domes and sculpted ice facades, designed to harvest solar energy while providing radiation shielding.\n\n- Economy and daily life\n  - Key activities: ice extraction, water processing, helium-3 and rare-earth ore trades, 3D-printed components, biotech research in microgravity, and high-efficiency solar manufacturing.\n  - Daily life features regulated power cycles, with most chores scheduled during daylight hours to maximize solar energy use. Food is often produced in algae and hydroponic farms, with synthetic flavorings and real-time nutripacks.\n  - Transportation relies on sealed transit tubes, electric hover trams, and personal drone deliveries for small items.\n\n- Culture, education, and life\n  - Education centers emphasize aeroponics, robotics, lunar geology, and astroethics. Public spaces host open-air lectures, physics demonstrations, and musical performances that echo the Moon’s quiet, expansive ambiance.\n  - Festivals and rituals celebrate solar angles, lunar cycles, and interplanetary cooperation—often blending Earth traditions with Moon-specific myths about endurance, ice, and light.\n  - Language is pragmatic and evolving, with shared terms from Earth languages and a Lunar Creole developed for quick, precise communication in fieldwork.\n\n- Notable features and landmarks\n  - Council Dome: the political heart and decision-making hub.\n  - CryoBank Plaza: storage facilities and a public museum of lunar ice history.\n  - Solar Terrace: a public space atop the canopies offering panoramic views of Earthrise.\n  - The Icewell Market: a hub for trade, provisioning, and social gathering.\n  - The Observatory Quarter: public observatories and private research facilities.\n\n- Challenges and flavor\n  - Radiation management, dust disruption, life-support logistics, and political balancing between Earth interests and lunar autonomy.\n  - Social tensio ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional setting, not a real place. If you’re aiming for a sci‑fi world or a story, here’s a detailed, self‑contained concept you can use or adapt. It treats Luna City as the capital of a Lunar Confederation on the Moon.
#
# Overview
# - Name: Luna City
# - Role: Political, scientific, economic, and cultural capital of the Lunar Confederation
# - Location: Near-side, equatorial region of the Moon, in a large basin that provides good Earth visibility and access to surface and orbital infrastructure
# - Population: Roughly 2 million residents, including scientists, engineers, government officials, educators, families, and a steady flow of new settlers and workers from Earth
# - Vibe: A high-tech, crowded, optimistic but pragmatic lunar metropolis—an arcology-heavy city that combines cutting-edge science with distinctive lunar culture
#
# Core concept
# Luna City is the central hub where lunar governance, research, industry, and culture converge. It’s built to withstand the Moon’s harsh environment while delivering Earthlike living conditions inside. Gravity is managed with rotating habitats and gravity-enabled districts, so many living spaces feel “Earthlike” while workspaces and manufacturing floors leverage microgravity where useful. The city is powered by a combination of solar arrays and compact nuclear microreactors, with ISRU (in-situ resource utilization) feeding oxygen, water, and building materials from lunar ice and regolith.
#
# Governance and politics
# - Government: The Lunar Confederation, a federal‑like union of settlements and districts, with Luna City as the seat of government. A Prime Director (elected for a fixed term) presides over a Council of Governors from major districts and a People’s Assembly that represents the wider citizenry.
# - Institutions: Lunar Court (courts and arbitration), Council of Science, Trade Guilds, and the Engineers’ Directorate.
# - Law: The Moon Charter guarantees property rights, resource access, labor protections, and civil liberties within the Confederation. National security is handled by the Lunar Guard, a civilian-military force with a strong civil‑military culture.
#
# Geography and districts
# - Central Spine: A vertical, gravity-controlled core district comprising rotating habitat rings that deliver Earthlike gravity (roughly 1g) to residential zones. The spine also houses data centers, medical facilities, and utilities.
# - Government Quarter: Where the Prime Director’s residence, Parliament, ministries, and the Supreme Court sit. Rich in public plazas and ceremonial spaces.
# - Science Quarter: Home to lunar laboratories, biotech and materials facilities, ISRU research stations, and the Lunar Observatory Array. Surrounded by testing grounds and clean rooms.
# - Commerce Ring: Banks, markets, startups, press, arts venues, tourism facilities, and lunar‑made crafts.
# - Residential Belt: Mixed‑density housing, family neighborhoods, schools, clinics, and community hubs. Many apartments are modular and self-sufficient.
# - Cultural Quarter: Museums, theaters, galleries, performance spaces, lunar festivals, and religious/spiritual centers with a Moon‑centered cosmology.
# - Orbital Interface: A hub at the edge of the city where trampolines and skybridges link to a surrounding orbital ring, shuttles, and space elevators.
#
# Architecture and technology
# - Architecture: Arcologies and tall spires built from regolith-concrete, reinforced graphene composites, and translucent solar glass. Public spaces blend lunar regolith aesthetics (textures, colors) with advanced polymers and metal alloys.
# - Gravity and living spaces: Some districts are in rotating modules that create stable 1g for residents; work areas and manufacturing floors may use lower gravity or zero-g environments for specialized tasks.
# - ISRU and materials: In-situ oxygen production, water extraction from ice, and regolith mining supply the city’s life-support and construction. Glassy domes and transparent tunnels connect districts and offer Earth‑visible skylines.
# - Energy: Solar farms on the farside, rooftop collectors, and compact nuclear microreactors for baseload power. Energy storage uses advanced batteries and supercapacitors.
# - Transportation: Within-city maglev/rail networks, surface shuttles (hoppers), and gravity elevators to the orbital ring. Short-range air taxis in a controlled, low-noise corridor.
#
# Economy
# - Core industries: Helium-3 and other lunar isotopes, water/ice mining from polar sites, high-precision manufacturing in microgravity, and lunar-arcology construction.
# - Trade: Luna City trades with Earth and with other lunar settlements for technology, food from Earth, and cultural goods. It also hosts a thriving startup scene focused on space tech, education, and media.
# - Currency and banking: A lunar credit system backed by a mix of mineral resources, energy credits, and government bonds.
#
# Society, culture, and daily life
# - Population culture: A blend of Earth cultures with a distinctly lunar identity—pragmatic, science-curious, and resilient. There’s a strong emphasis on education, safety, community, and space exploration heritage.
# - Education: The Luna Academy and affiliate universities offer STEM-heavy curricula, with parallel tracks in arts, history, and lunar culture. Exams and career tracks are tied to the Confederation’s governance and industry needs.
# - Healthcare and well-being: Comprehensive lunar clinics and a major medical center; focus on long-term adaptation to lunar living, mental health, and rehabilitation after spaceflight.
# - Festivals and religion: Moon-focused festivals (new lunar year, harvests from hydroponics, meteor shower celebrations) and a range of beliefs including secular humanism, lunar mysticism tied to cycles, and interfaith dialogue.
# - Social issues: Balancing Earth-born citizens and long-term settlers; managing resource allocation; mental health in isolated environments; citizenship rights for hybrid Earth‑Moon residents.
#
# Landmarks and notable places
# - The Aurora Dome: A massive glass dome offering a citywide view of Earth during daytime and a light show at night.
# - The Hollow Sphere: The central government complex, a geodesic structure that hosts parliaments, courts, and ceremonial spaces.
# - Echo Dome: A concert venue known for acoustics adapted to Moon gravity and a rotating audience platform.
# - Sea of Tranquility Market: A bustling commercial zone with lunar crafts, biotech displays, and food halls using hydroponic produce.
# - The Umbra Gate: A ceremonial gate at the edge of the Government Quarter, used for official processions and lunar rites.
# - Gravity Towers: A cluster of tall residential towers connected by skybridges and public transit nodes, each with its own microclimate domes.
#
# Notable people (fictional examples)
# - Prime Director Amina Zhao (reigning leader, technocrat with a background in ISRU policy)
# - Dr. Ishaan Khatri (chief scientist, materials expert, leads the Moon Lab)
# - Commander Rayna Voss (head of the Lunar Guard, focuses on civil-military trust and safety)
# - Lira Sol (artist-educator, runs the Lunar Academy’s public outreach and cultural programs)
#
# Current challenges and themes
# - Water and energy security: Ensuring clean water supply and stable power for a growing city while expanding ISRU.
# - Resource governance: Fair access to lunar resources among districts and new settlers.
# - Earth–Moon politics: Balancing Earthly oversight, planetary markets, and local autonomy.
# - Psychological well-being: Long-term life in a constrained, high-density environment; social cohesion and mental health.
# - Security threats: Sabotage or theft of ISRU assets, anomalies in polar ice, and cyber-physical risks to the Orbital Interface.
#
# Story hooks and plot ideas
# - A prominent scientist disappears on the eve of a major ISRU breakthrough; clues point to a covert faction within the Engineers’ Guild.
# - An Earth-backed corporate project to mine a volatile ice deposit triggers environmental and political tensions in Luna City.
# - A protest movement challenges resource distribution, forcing the government to navigate civil liberties and public safety during a tense standoff.
# - A new gravity ring module malfunctions, altering living conditions for thousands and forcing a high-stakes rescue and repair operation.
# - A cultural festival reveals a long-buried lunar myth that questions humanity’s relationship with the Moon and with Earth.
#
# If you want, I can tailor Luna City to a specific tone (hopeful utopia, gritty cyberpunk, political thriller, etc.), or help you build a map, write a scene, or create a character roster for a story or game set there. Would you like a shorter, scene-ready description, or a full-fledged, canon-like “encyclopedia entry” for a project?

# %%
sys_prompt = "You are science fiction writer, at request, create a capital city."
sci_agent = create_agent(model="gpt-5-nano", system_prompt=sys_prompt)
prompt = "What is a capital of a moon?"
response = sci_agent.invoke(
    {"messages": [prompt]}
)

# %%
print(response['messages'][1].content)
# Out:
# In a fictional universe, a moon could have its own capital. Here’s a vivid option you can use:
#
# Capital: Crescentia
# Moon: Noctis (the Moon of a gas giant called Asterion)
#
# What Crescentia is like:
# - Location and feel: Built along the rim of a colossal impact crater, the city sprawls up the crater walls in a ring of arcologies. Glassy towers reflect the stars, while green terraces spill down the slopes.
# - Architecture: A blend of translucent basalt, solar-glass, and living walls. Skyscrapers float on magnetic rails; sky-bridges weave a web above the crater floor.
# - Centerpiece: The Beacon Spire, a 20-km-tall tower at the crater’s heart that harvests solar energy and houses the lunar archives—a colossal library of recorded histories, songs, and maps.
# - Government: The Crateral Assembly rules Crescentia, a council drawn from each lunar district. Legislation is debated in the Great Lantern Hall, with decisions sealed by a ceremonial beacon in the Spire’s apex.
# - Economy: Energy mining from lunar deposits, water ice harvesting, biotech grown in microgravity, and instrument trade that translates seismic and luminescent signals into currency.
# - Culture: Festivals of light during the long dawn, moon-dance rituals in the low gravity, and a nocturnal market that hums with traders and storytellers.
# - Daily life: People navigate with magnetic railways and gravity-adjusted sidewalks; many homes double as micro-labs for citizen-scientists.
#
# If you’d like, I can tailor Crescentia to a different moon (size, gravity, technological level, or cultural vibe), or craft another capital with its own name and backstory.
