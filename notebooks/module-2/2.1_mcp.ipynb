# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
                "transport": "stdio",
                "command": "python",
                "args": ["resources/2.1_mcp_server.py"],
            }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content
prompt
# Out:
# '\n    You are a helpful assistant that answers user questions about LangChain, LangGraph and LangSmith.\n\n    You can use the following tools/resources to answer user questions:\n    - search_web: Search the web for information\n    - github_file: Access the langchain-ai repo files\n\n    If the user asks a question that is not related to LangChain, LangGraph or LangSmith, you should say "I\'m sorry, I can only answer questions about LangChain, LangGraph and LangSmith."\n\n    You may try multiple tool and resource calls to answer the user\'s question.\n\n    You may also ask clarifying questions to the user to better understand their question.\n    '

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library")]},
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='f5cfc433-9d4a-4a2f-94a7-1ac1c6783d74'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 271, 'total_tokens': 363, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DVkZPQsfRTwlMRrMJp7UeTtJyUcm6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d9d3d-9c89-7f83-bb73-824c031dc9aa-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_v7BDzGgEYaGgNlTJ9QPnJknE', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 92, 'total_tokens': 363, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://reference.langchain.com/python/langchain-mcp-adapters/tools/load_mcp_tools",\n      "title": "load_mcp_tools | langchain_mcp_adapters | LangChain Reference",\n      "content": "##### LangChain. ##### LangChain Core. ##### MCP Adapters. ##### LangChain Classic. ## LangChain Assistant. `Enter` to send•`Shift+Enter` new line. # load\\\\_mcp\\\\_tools. | `session`\\\\* | `ClientSession | None` | The MCP client session. If `None`, connection must be provided. | `connection` | `Connection | None` | Default:`None`  Connection config to create a new session if session is `None`. | `callbacks` | `Callbacks | None` | Default:`None`  Optional `Callbacks` for handling notifications and events. | `tool_interceptors` | `list[ToolCallInterceptor] | None` | Default:`None` |. | `server_name` | `str | None` | Default:`None` |. If `None`, connection must be provided. Connection config to create a new session if session is `None`. Optional `Callbacks` for handling notifications and events. Load all available MCP tools and convert them to LangChain tools. Optional list of interceptors for tool call processing. Name of the server these tools belong to. If `True` and `server_name` is provided, tool names will be. prefixed w/ server name (e.g., `\\"weather_search\\"` instead of `\\"search\\"`).",\n      "score": 0.99999833,\n      "raw_content": null\n    },\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "LangChain - Changelog | MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.99999595,\n      "raw_content": null\n    },\n    {\n      "url": "https://reference.langchain.com/python/langchain-mcp-adapters/langchain_mcp_adapters",\n      "title": "langchain_mcp_adapters | LangChain Reference",\n      "content": "##### LangChain. ##### MCP Adapters. ## LangChain Assistant. # langchain\\\\_mcp\\\\_adapters. LangChain MCP Adapters - Connect MCP servers with LangChain applications. This package provides adapters to connect MCP (Model Context Protocol) servers. with LangChain applications, converting MCP tools, prompts, and resources into. Prompts adapter for converting MCP prompts to LangChain messages. This module provides functionality to convert MCP prompt messages into LangChain. Resources adapter for converting MCP resources to LangChain Blob objects. This module provides functionality to convert MCP resources into LangChain Blob. Client for connecting to multiple MCP servers and loading LC tools/resources. to multiple MCP servers and loading tools, prompts, and resources from them. Session management for different MCP transport types. This module provides connection configurations and session management for various. Tools adapter for converting MCP tools to LangChain  ...
#               AIMessage(content='Here’s a concise overview of the langchain-mcp-adapters library and what it’s for.\n\nWhat it is\n- A bridge between Anthropic’s Model Context Protocol (MCP) tool servers and LangChain (and LangGraph). It converts MCP tools, prompts, and resources into LangChain/LangGraph-compatible artifacts so you can use MCP tools inside LangChain agents and workflows.\n- It supports interacting with multiple MCP servers at once, so your LangChain applications can pull tools from a whole MCP ecosystem rather than a single server.\n\nKey capabilities\n- Tools adapter: Converts MCP tools into LangChain-compatible Tool objects that you can call from LangChain agents.\n- Prompts adapter: Converts MCP prompts into LangChain messages/prompts.\n- Resources adapter: Converts MCP resources into LangChain Blob-like objects.\n- Multi-server client: A client that can connect to multiple MCP servers and load tools, prompts, and resources from them.\n- Session and connection management: Provides session handling and connection configurations for MCP transports.\n- Interceptors and lifecycle: Defines interceptor interfaces for tool call processing (e.g., handling notifications and events during tool use).\n- Server name prefixing: Optional behavior to prefix tool names with the server name, which helps disambiguate tools from different servers.\n- Configurability: Options for per-server or global timeouts, and authentication (auth providers) to secure MCP servers.\n\nWhy you’d use it\n- If you want to leverage the large and growing ecosystem of MCP tool servers from within LangChain/LangGraph without manual per-tool adapters.\n- To run agents that can pull tools from multiple MCP servers in parallel, enabling richer tool access and orchestration.\n\nWhat you’ll typically do (high level)\n- Install the library (Python: langchain-mcp-adapters; Node: @langchain/mcp-adapters).\n- Configure one or more MCP servers (including auth if needed).\n- Use the MCP adapters to load MCP tools into LangChain as LangChain-compatible tools (optionally with server-name prefixing).\n- Use those tools inside LangChain agents, chains, or LangGraph workflows as you would with native LangChain tools.\n\nWhere to learn more (docs and references)\n- load_mcp_tools reference (Python): load_mcp_tools | langchain_mcp_adapters\n- langchain_mcp_adapters module reference (Python): langchain_mcp_adapters\n- MCP adapters changelog (context and motivation): MCP Adapters for LangChain and LangGraph\n- Medium guide: The Complete Guide to langchain-mcp-adapters (overview and concepts)\n- npm package page (Node/JS): @langchain/mcp-adapters\n\nNotes and nuances\n- MCP is an open standard from Anthropic for connecting data sources and tools; MCP adapters help LangChain/LangGraph interact with that ecosystem.\n- The adapters are designed to make it easy to aggregate tools from multiple MCP servers, which can simplify building multi-tool agents and reduce custom integration work.\n\nWould you like:\n- A quick code snippet showing how to load MCP tools into LangChain in Python, or\n- A deeper dive into one of the components (tools adapter, prompts adapter, or the multi-server client) with example configurations?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2515, 'prompt_tokens': 1895, 'total_tokens': 4410, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1856, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DVkZUhdGhSUHVpqB6LDm4TXZGbyaY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9d3d-b294-7963-ab29-681a4669b7f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1895, 'output_tokens': 2515, 'total_tokens': 4410, 'input_token_details': {' ...

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": [
                "mcp-server-time",
                "--local-timezone=America/New_York"
            ]
        }
    }
)

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

pprint(response)
